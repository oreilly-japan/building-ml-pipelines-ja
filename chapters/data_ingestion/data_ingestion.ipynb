# %% [markdown]
# # Data Ingestion

# %% [markdown]
# ## Setup

# %% [markdown]
# ### Install the packages

# %%
# !pip install -U tensorflow==2.4.1 tfx==0.27.0 pandas==1.2.3
# Out:
# Requirement already up-to-date: tensorflow==2.4.1 in /usr/local/lib/python3.7/dist-packages (2.4.1)
# Requirement already up-to-date: tfx==0.27.0 in /usr/local/lib/python3.7/dist-packages (0.27.0)
# Requirement already up-to-date: pandas==1.2.3 in /usr/local/lib/python3.7/dist-packages (1.2.3)
# Requirement already satisfied, skipping upgrade: h5py~=2.10.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.4.1) (2.10.0)
# Requirement already satisfied, skipping upgrade: flatbuffers~=1.12.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.4.1) (1.12)
# Requirement already satisfied, skipping upgrade: wheel~=0.35 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.4.1) (0.36.2)
# Requirement already satisfied, skipping upgrade: wrapt~=1.12.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.4.1) (1.12.1)
# Requirement already satisfied, skipping upgrade: absl-py~=0.10 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.4.1) (0.10.0)
# Requirement already satisfied, skipping upgrade: astunparse~=1.6.3 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.4.1) (1.6.3)
# Requirement already satisfied, skipping upgrade: keras-preprocessing~=1.1.2 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.4.1) (1.1.2)
# Requirement already satisfied, skipping upgrade: termcolor~=1.1.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.4.1) (1.1.0)
# Requirement already satisfied, skipping upgrade: typing-extensions~=3.7.4 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.4.1) (3.7.4.3)
# Requirement already satisfied, skipping upgrade: protobuf>=3.9.2 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.4.1) (3.12.4)
# Requirement already satisfied, skipping upgrade: google-pasta~=0.2 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.4.1) (0.2.0)
# Requirement already satisfied, skipping upgrade: tensorflow-estimator<2.5.0,>=2.4.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.4.1) (2.4.0)
# Requirement already satisfied, skipping upgrade: numpy~=1.19.2 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.4.1) (1.19.5)
# Requirement already satisfied, skipping upgrade: opt-einsum~=3.3.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.4.1) (3.3.0)
# Requirement already satisfied, skipping upgrade: grpcio~=1.32.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.4.1) (1.32.0)
# Requirement already satisfied, skipping upgrade: six~=1.15.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.4.1) (1.15.0)
# Requirement already satisfied, skipping upgrade: gast==0.3.3 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.4.1) (0.3.3)
# Requirement already satisfied, skipping upgrade: tensorboard~=2.4 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.4.1) (2.4.1)
# Requirement already satisfied, skipping upgrade: pyarrow<3,>=1 in /usr/local/lib/python3.7/dist-packages (from tfx==0.27.0) (2.0.0)
# Requirement already satisfied, skipping upgrade: google-api-python-client<2,>=1.7.8 in /usr/local/lib/python3.7/dist-packages (from tfx==0.27.0) (1.12.8)
# Requirement already satisfied, skipping upgrade: ml-metadata<0.28,>=0.27 in /usr/local/lib/python3.7/dist-packages (from tfx==0.27.0) (0.27.0)
# Requirement already satisfied, skipping upgrade: tfx-bsl<0.28,>=0.27 in /usr/local/lib/python3.7/dist-packages (from tfx==0.27.0) (0.27.1)
# Requirement already satisfied, skipping upgrade: attrs<21,>=19.3.0 in /usr/local/lib/python3.7/dist-packages (from tfx==0.27.0) (20.3.0)
# Requirement already satisfied, skipping upgrade: tensorflow-data-validation<0.28,>=0.27 in /usr/local/lib/python3.7/dist-packages (from tfx==0.27.0) (0.27.0)
# Requirement already satisfied, skipping upgrade: click<8,>=7 in /usr/local/lib/python3.7/dist-packages (from tfx==0.27.0) (7.1.2)
# Requirement already satisfied, skipping upgrade: docker<5,>=4.1 in /usr/local/lib/python3.7/dist-packages (from tfx==0.27.0) (4.4.4)
# Requirement already satisfied, skipping upgrade: tensorflow-transform<0.28,>=0.27 in /usr/local/lib/python3.7/dist-packages (from tfx==0.27.0) (0.27.0)
# Requirement already satisfied, skipping upgrade: tensorflow-serving-api!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,<3,>=1.15 in /usr/local/lib/python3.7/dist-packages (from tfx==0.27.0) (2.4.1)
# Requirement already satisfied, skipping upgrade: keras-tuner<1.0.2,>=1 in /usr/local/lib/python3.7/dist-packages (from tfx==0.27.0) (1.0.1)
# Requirement already satisfied, skipping upgrade: tensorflow-hub<0.10,>=0.9.0 in /usr/local/lib/python3.7/dist-packages (from tfx==0.27.0) (0.9.0)
# Requirement already satisfied, skipping upgrade: jinja2<3,>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from tfx==0.27.0) (2.11.3)
# Requirement already satisfied, skipping upgrade: tensorflow-cloud<0.2,>=0.1 in /usr/local/lib/python3.7/dist-packages (from tfx==0.27.0) (0.1.13)
# Requirement already satisfied, skipping upgrade: tensorflow-model-analysis<0.28,>=0.27 in /usr/local/lib/python3.7/dist-packages (from tfx==0.27.0) (0.27.0)
# Requirement already satisfied, skipping upgrade: apache-beam[gcp]<3,>=2.27 in /usr/local/lib/python3.7/dist-packages (from tfx==0.27.0) (2.28.0)
# Requirement already satisfied, skipping upgrade: kubernetes<12,>=10.0.1 in /usr/local/lib/python3.7/dist-packages (from tfx==0.27.0) (11.0.0)
# Requirement already satisfied, skipping upgrade: pyyaml<6,>=3.12 in /usr/local/lib/python3.7/dist-packages (from tfx==0.27.0) (3.13)
# Requirement already satisfied, skipping upgrade: ml-pipelines-sdk==0.27.0 in /usr/local/lib/python3.7/dist-packages (from tfx==0.27.0) (0.27.0)
# Requirement already satisfied, skipping upgrade: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas==1.2.3) (2.8.1)
# Requirement already satisfied, skipping upgrade: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas==1.2.3) (2018.9)
# Requirement already satisfied, skipping upgrade: setuptools in /usr/local/lib/python3.7/dist-packages (from protobuf>=3.9.2->tensorflow==2.4.1) (54.1.2)
# Requirement already satisfied, skipping upgrade: werkzeug>=0.11.15 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.4->tensorflow==2.4.1) (1.0.1)
# Requirement already satisfied, skipping upgrade: markdown>=2.6.8 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.4->tensorflow==2.4.1) (3.3.4)
# Requirement already satisfied, skipping upgrade: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.4->tensorflow==2.4.1) (1.8.0)
# Requirement already satisfied, skipping upgrade: requests<3,>=2.21.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.4->tensorflow==2.4.1) (2.23.0)
# Requirement already satisfied, skipping upgrade: google-auth<2,>=1.6.3 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.4->tensorflow==2.4.1) (1.27.1)
# Requirement already satisfied, skipping upgrade: google-auth-oauthlib<0.5,>=0.4.1 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.4->tensorflow==2.4.1) (0.4.3)
# Requirement already satisfied, skipping upgrade: httplib2<1dev,>=0.15.0 in /usr/local/lib/python3.7/dist-packages (from google-api-python-client<2,>=1.7.8->tfx==0.27.0) (0.17.4)
# Requirement already satisfied, skipping upgrade: uritemplate<4dev,>=3.0.0 in /usr/local/lib/python3.7/dist-packages (from google-api-python-client<2,>=1.7.8->tfx==0.27.0) (3.0.1)
# Requirement already satisfied, skipping upgrade: google-auth-httplib2>=0.0.3 in /usr/local/lib/python3.7/dist-packages (from google-api-python-client<2,>=1.7.8->tfx==0.27.0) (0.0.4)
# Requirement already satisfied, skipping upgrade: google-api-core<2dev,>=1.21.0 in /usr/local/lib/python3.7/dist-packages (from google-api-python-client<2,>=1.7.8->tfx==0.27.0) (1.26.1)
# Requirement already satisfied, skipping upgrade: tensorflow-metadata<0.28,>=0.27 in /usr/local/lib/python3.7/dist-packages (from tfx-bsl<0.28,>=0.27->tfx==0.27.0) (0.27.0)
# Requirement already satisfied, skipping upgrade: joblib<0.15,>=0.12 in /usr/local/lib/python3.7/dist-packages (from tensorflow-data-validation<0.28,>=0.27->tfx==0.27.0) (0.14.1)
# Requirement already satisfied, skipping upgrade: websocket-client>=0.32.0 in /usr/local/lib/python3.7/dist-packages (from docker<5,>=4.1->tfx==0.27.0) (0.58.0)
# Requirement already satisfied, skipping upgrade: pydot<2,>=1.2 in /usr/local/lib/python3.7/dist-packages (from tensorflow-transform<0.28,>=0.27->tfx==0.27.0) (1.3.0)
# Requirement already satisfied, skipping upgrade: colorama in /usr/local/lib/python3.7/dist-packages (from keras-tuner<1.0.2,>=1->tfx==0.27.0) (0.4.4)
# Requirement already satisfied, skipping upgrade: future in /usr/local/lib/python3.7/dist-packages (from keras-tuner<1.0.2,>=1->tfx==0.27.0) (0.16.0)
# Requirement already satisfied, skipping upgrade: scipy in /usr/local/lib/python3.7/dist-packages (from keras-tuner<1.0.2,>=1->tfx==0.27.0) (1.4.1)
# Requirement already satisfied, skipping upgrade: scikit-learn in /usr/local/lib/python3.7/dist-packages (from keras-tuner<1.0.2,>=1->tfx==0.27.0) (0.22.2.post1)
# Requirement already satisfied, skipping upgrade: tabulate in /usr/local/lib/python3.7/dist-packages (from keras-tuner<1.0.2,>=1->tfx==0.27.0) (0.8.9)
# Requirement already satisfied, skipping upgrade: tqdm in /usr/local/lib/python3.7/dist-packages (from keras-tuner<1.0.2,>=1->tfx==0.27.0) (4.41.1)
# Requirement already satisfied, skipping upgrade: terminaltables in /usr/local/lib/python3.7/dist-packages (from keras-tuner<1.0.2,>=1->tfx==0.27.0) (3.1.0)
# Requirement already satisfied, skipping upgrade: MarkupSafe>=0.23 in /usr/local/lib/python3.7/dist-packages (from jinja2<3,>=2.7.3->tfx==0.27.0) (1.1.1)
# Requirement already satisfied, skipping upgrade: google-cloud-storage in /usr/local/lib/python3.7/dist-packages (from tensorflow-cloud<0.2,>=0.1->tfx==0.27.0) (1.18.1)
# Requirement already satisfied, skipping upgrade: tensorflow-datasets<3.1.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow-cloud<0.2,>=0.1->tfx==0.27.0) (3.0.0)
# Requirement already satisfied, skipping upgrade: ipywidgets<8,>=7 in /usr/local/lib/python3.7/dist-packages (from tensorflow-model-analysis<0.28,>=0.27->tfx==0.27.0) (7.6.3)
# Requirement already satisfied, skipping upgrade: ipython<8,>=7 in /usr/local/lib/python3.7/dist-packages (from tensorflow-model-analysis<0.28,>=0.27->tfx==0.27.0) (7.21.0)
# Requirement already satisfied, skipping upgrade: fastavro<2,>=0.21.4 in /usr/local/lib/python3.7/dist-packages (from apache-beam[gcp]<3,>=2.27->tfx==0.27.0) (1.3.4)
# Requirement already satisfied, skipping upgrade: avro-python3!=1.9.2,<1.10.0,>=1.8.1 in /usr/local/lib/python3.7/dist-packages (from apache-beam[gcp]<3,>=2.27->tfx==0.27.0) (1.9.2.1)
# Requirement already satisfied, skipping upgrade: mock<3.0.0,>=1.0.1 in /usr/local/lib/python3.7/dist-packages (from apache-beam[gcp]<3,>=2.27->tfx==0.27.0) (2.0.0)
# Requirement already satisfied, skipping upgrade: dill<0.3.2,>=0.3.1.1 in /usr/local/lib/python3.7/dist-packages (from apache-beam[gcp]<3,>=2.27->tfx==0.27.0) (0.3.1.1)
# Requirement already satisfied, skipping upgrade: crcmod<2.0,>=1.7 in /usr/local/lib/python3.7/dist-packages (from apache-beam[gcp]<3,>=2.27->tfx==0.27.0) (1.7)
# Requirement already satisfied, skipping upgrade: oauth2client<5,>=2.0.1 in /usr/local/lib/python3.7/dist-packages (from apache-beam[gcp]<3,>=2.27->tfx==0.27.0) (4.1.3)
# Requirement already satisfied, skipping upgrade: hdfs<3.0.0,>=2.1.0 in /usr/local/lib/python3.7/dist-packages (from apache-beam[gcp]<3,>=2.27->tfx==0.27.0) (2.6.0)
# Requirement already satisfied, skipping upgrade: pymongo<4.0.0,>=3.8.0 in /usr/local/lib/python3.7/dist-packages (from apache-beam[gcp]<3,>=2.27->tfx==0.27.0) (3.11.3)
# Requirement already satisfied, skipping upgrade: grpcio-gcp<1,>=0.2.2; extra == "gcp" in /usr/local/lib/python3.7/dist-packages (from apache-beam[gcp]<3,>=2.27->tfx==0.27.0) (0.2.2)
# Requirement already satisfied, skipping upgrade: google-cloud-bigtable<2,>=0.31.1; extra == "gcp" in /usr/local/lib/python3.7/dist-packages (from apache-beam[gcp]<3,>=2.27->tfx==0.27.0) (1.7.0)
# Requirement already satisfied, skipping upgrade: google-apitools<0.5.32,>=0.5.31; extra == "gcp" in /usr/local/lib/python3.7/dist-packages (from apache-beam[gcp]<3,>=2.27->tfx==0.27.0) (0.5.31)
# Requirement already satisfied, skipping upgrade: cachetools<5,>=3.1.0; extra == "gcp" in /usr/local/lib/python3.7/dist-packages (from apache-beam[gcp]<3,>=2.27->tfx==0.27.0) (4.2.1)
# Requirement already satisfied, skipping upgrade: google-cloud-dlp<2,>=0.12.0; extra == "gcp" in /usr/local/lib/python3.7/dist-packages (from apache-beam[gcp]<3,>=2.27->tfx==0.27.0) (1.0.0)
# Requirement already satisfied, skipping upgrade: google-cloud-videointelligence<2,>=1.8.0; extra == "gcp" in /usr/local/lib/python3.7/dist-packages (from apache-beam[gcp]<3,>=2.27->tfx==0.27.0) (1.16.1)
# Requirement already satisfied, skipping upgrade: google-cloud-pubsub<2,>=0.39.0; extra == "gcp" in /usr/local/lib/python3.7/dist-packages (from apache-beam[gcp]<3,>=2.27->tfx==0.27.0) (1.7.0)
# Requirement already satisfied, skipping upgrade: google-cloud-spanner<2,>=1.13.0; extra == "gcp" in /usr/local/lib/python3.7/dist-packages (from apache-beam[gcp]<3,>=2.27->tfx==0.27.0) (1.19.1)
# Requirement already satisfied, skipping upgrade: google-cloud-bigquery<2,>=1.6.0; extra == "gcp" in /usr/local/lib/python3.7/dist-packages (from apache-beam[gcp]<3,>=2.27->tfx==0.27.0) (1.21.0)
# Requirement already satisfied, skipping upgrade: google-cloud-datastore<2,>=1.7.1; extra == "gcp" in /usr/local/lib/python3.7/dist-packages (from apache-beam[gcp]<3,>=2.27->tfx==0.27.0) (1.8.0)
# Requirement already satisfied, skipping upgrade: google-cloud-language<2,>=1.3.0; extra == "gcp" in /usr/local/lib/python3.7/dist-packages (from apache-beam[gcp]<3,>=2.27->tfx==0.27.0) (1.3.0)
# Requirement already satisfied, skipping upgrade: google-cloud-core<2,>=0.28.1; extra == "gcp" in /usr/local/lib/python3.7/dist-packages (from apache-beam[gcp]<3,>=2.27->tfx==0.27.0) (1.0.3)
# Requirement already satisfied, skipping upgrade: google-cloud-build<3,>=2.0.0; extra == "gcp" in /usr/local/lib/python3.7/dist-packages (from apache-beam[gcp]<3,>=2.27->tfx==0.27.0) (2.0.0)
# Requirement already satisfied, skipping upgrade: google-cloud-vision<2,>=0.38.0; extra == "gcp" in /usr/local/lib/python3.7/dist-packages (from apache-beam[gcp]<3,>=2.27->tfx==0.27.0) (1.0.0)
# Requirement already satisfied, skipping upgrade: urllib3>=1.24.2 in /usr/local/lib/python3.7/dist-packages (from kubernetes<12,>=10.0.1->tfx==0.27.0) (1.24.3)
# Requirement already satisfied, skipping upgrade: requests-oauthlib in /usr/local/lib/python3.7/dist-packages (from kubernetes<12,>=10.0.1->tfx==0.27.0) (1.3.0)
# Requirement already satisfied, skipping upgrade: certifi>=14.05.14 in /usr/local/lib/python3.7/dist-packages (from kubernetes<12,>=10.0.1->tfx==0.27.0) (2020.12.5)
# Requirement already satisfied, skipping upgrade: importlib-metadata; python_version < "3.8" in /usr/local/lib/python3.7/dist-packages (from markdown>=2.6.8->tensorboard~=2.4->tensorflow==2.4.1) (3.7.2)
# Requirement already satisfied, skipping upgrade: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard~=2.4->tensorflow==2.4.1) (3.0.4)
# Requirement already satisfied, skipping upgrade: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard~=2.4->tensorflow==2.4.1) (2.10)
# Requirement already satisfied, skipping upgrade: rsa<5,>=3.1.4; python_version >= "3.6" in /usr/local/lib/python3.7/dist-packages (from google-auth<2,>=1.6.3->tensorboard~=2.4->tensorflow==2.4.1) (4.7.2)
# Requirement already satisfied, skipping upgrade: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.7/dist-packages (from google-auth<2,>=1.6.3->tensorboard~=2.4->tensorflow==2.4.1) (0.2.8)
# Requirement already satisfied, skipping upgrade: packaging>=14.3 in /usr/local/lib/python3.7/dist-packages (from google-api-core<2dev,>=1.21.0->google-api-python-client<2,>=1.7.8->tfx==0.27.0) (20.9)
# Requirement already satisfied, skipping upgrade: googleapis-common-protos<2.0dev,>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from google-api-core<2dev,>=1.21.0->google-api-python-client<2,>=1.7.8->tfx==0.27.0) (1.53.0)
# Requirement already satisfied, skipping upgrade: pyparsing>=2.1.4 in /usr/local/lib/python3.7/dist-packages (from pydot<2,>=1.2->tensorflow-transform<0.28,>=0.27->tfx==0.27.0) (2.4.7)
# Requirement already satisfied, skipping upgrade: google-resumable-media<0.5.0dev,>=0.3.1 in /usr/local/lib/python3.7/dist-packages (from google-cloud-storage->tensorflow-cloud<0.2,>=0.1->tfx==0.27.0) (0.4.1)
# Requirement already satisfied, skipping upgrade: promise in /usr/local/lib/python3.7/dist-packages (from tensorflow-datasets<3.1.0->tensorflow-cloud<0.2,>=0.1->tfx==0.27.0) (2.3)
# Requirement already satisfied, skipping upgrade: jupyterlab-widgets>=1.0.0; python_version >= "3.6" in /usr/local/lib/python3.7/dist-packages (from ipywidgets<8,>=7->tensorflow-model-analysis<0.28,>=0.27->tfx==0.27.0) (1.0.0)
# Requirement already satisfied, skipping upgrade: traitlets>=4.3.1 in /usr/local/lib/python3.7/dist-packages (from ipywidgets<8,>=7->tensorflow-model-analysis<0.28,>=0.27->tfx==0.27.0) (5.0.5)
# Requirement already satisfied, skipping upgrade: nbformat>=4.2.0 in /usr/local/lib/python3.7/dist-packages (from ipywidgets<8,>=7->tensorflow-model-analysis<0.28,>=0.27->tfx==0.27.0) (5.1.2)
# Requirement already satisfied, skipping upgrade: ipykernel>=4.5.1 in /usr/local/lib/python3.7/dist-packages (from ipywidgets<8,>=7->tensorflow-model-analysis<0.28,>=0.27->tfx==0.27.0) (4.10.1)
# Requirement already satisfied, skipping upgrade: widgetsnbextension~=3.5.0 in /usr/local/lib/python3.7/dist-packages (from ipywidgets<8,>=7->tensorflow-model-analysis<0.28,>=0.27->tfx==0.27.0) (3.5.1)
# Requirement already satisfied, skipping upgrade: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from ipython<8,>=7->tensorflow-model-analysis<0.28,>=0.27->tfx==0.27.0) (3.0.18)
# Requirement already satisfied, skipping upgrade: pickleshare in /usr/local/lib/python3.7/dist-packages (from ipython<8,>=7->tensorflow-model-analysis<0.28,>=0.27->tfx==0.27.0) (0.7.5)
# Requirement already satisfied, skipping upgrade: jedi>=0.16 in /usr/local/lib/python3.7/dist-packages (from ipython<8,>=7->tensorflow-model-analysis<0.28,>=0.27->tfx==0.27.0) (0.18.0)
# Requirement already satisfied, skipping upgrade: backcall in /usr/local/lib/python3.7/dist-packages (from ipython<8,>=7->tensorflow-model-analysis<0.28,>=0.27->tfx==0.27.0) (0.2.0)
# Requirement already satisfied, skipping upgrade: pygments in /usr/local/lib/python3.7/dist-packages (from ipython<8,>=7->tensorflow-model-analysis<0.28,>=0.27->tfx==0.27.0) (2.6.1)
# Requirement already satisfied, skipping upgrade: pexpect>4.3; sys_platform != "win32" in /usr/local/lib/python3.7/dist-packages (from ipython<8,>=7->tensorflow-model-analysis<0.28,>=0.27->tfx==0.27.0) (4.8.0)
# Requirement already satisfied, skipping upgrade: decorator in /usr/local/lib/python3.7/dist-packages (from ipython<8,>=7->tensorflow-model-analysis<0.28,>=0.27->tfx==0.27.0) (4.4.2)
# Requirement already satisfied, skipping upgrade: pbr>=0.11 in /usr/local/lib/python3.7/dist-packages (from mock<3.0.0,>=1.0.1->apache-beam[gcp]<3,>=2.27->tfx==0.27.0) (5.5.1)
# Requirement already satisfied, skipping upgrade: pyasn1>=0.1.7 in /usr/local/lib/python3.7/dist-packages (from oauth2client<5,>=2.0.1->apache-beam[gcp]<3,>=2.27->tfx==0.27.0) (0.4.8)
# Requirement already satisfied, skipping upgrade: docopt in /usr/local/lib/python3.7/dist-packages (from hdfs<3.0.0,>=2.1.0->apache-beam[gcp]<3,>=2.27->tfx==0.27.0) (0.6.2)
# Requirement already satisfied, skipping upgrade: grpc-google-iam-v1<0.13dev,>=0.12.3 in /usr/local/lib/python3.7/dist-packages (from google-cloud-bigtable<2,>=0.31.1; extra == "gcp"->apache-beam[gcp]<3,>=2.27->tfx==0.27.0) (0.12.3)
# Requirement already satisfied, skipping upgrade: fasteners>=0.14 in /usr/local/lib/python3.7/dist-packages (from google-apitools<0.5.32,>=0.5.31; extra == "gcp"->apache-beam[gcp]<3,>=2.27->tfx==0.27.0) (0.16)
# Requirement already satisfied, skipping upgrade: libcst>=0.2.5 in /usr/local/lib/python3.7/dist-packages (from google-cloud-build<3,>=2.0.0; extra == "gcp"->apache-beam[gcp]<3,>=2.27->tfx==0.27.0) (0.3.17)
# Requirement already satisfied, skipping upgrade: proto-plus>=0.4.0 in /usr/local/lib/python3.7/dist-packages (from google-cloud-build<3,>=2.0.0; extra == "gcp"->apache-beam[gcp]<3,>=2.27->tfx==0.27.0) (1.18.1)
# Requirement already satisfied, skipping upgrade: oauthlib>=3.0.0 in /usr/local/lib/python3.7/dist-packages (from requests-oauthlib->kubernetes<12,>=10.0.1->tfx==0.27.0) (3.1.0)
# Requirement already satisfied, skipping upgrade: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata; python_version < "3.8"->markdown>=2.6.8->tensorboard~=2.4->tensorflow==2.4.1) (3.4.1)
# Requirement already satisfied, skipping upgrade: ipython-genutils in /usr/local/lib/python3.7/dist-packages (from traitlets>=4.3.1->ipywidgets<8,>=7->tensorflow-model-analysis<0.28,>=0.27->tfx==0.27.0) (0.2.0)
# Requirement already satisfied, skipping upgrade: jsonschema!=2.5.0,>=2.4 in /usr/local/lib/python3.7/dist-packages (from nbformat>=4.2.0->ipywidgets<8,>=7->tensorflow-model-analysis<0.28,>=0.27->tfx==0.27.0) (2.6.0)
# Requirement already satisfied, skipping upgrade: jupyter-core in /usr/local/lib/python3.7/dist-packages (from nbformat>=4.2.0->ipywidgets<8,>=7->tensorflow-model-analysis<0.28,>=0.27->tfx==0.27.0) (4.7.1)
# Requirement already satisfied, skipping upgrade: jupyter-client in /usr/local/lib/python3.7/dist-packages (from ipykernel>=4.5.1->ipywidgets<8,>=7->tensorflow-model-analysis<0.28,>=0.27->tfx==0.27.0) (5.3.5)
# Requirement already satisfied, skipping upgrade: tornado>=4.0 in /usr/local/lib/python3.7/dist-packages (from ipykernel>=4.5.1->ipywidgets<8,>=7->tensorflow-model-analysis<0.28,>=0.27->tfx==0.27.0) (5.1.1)
# Requirement already satisfied, skipping upgrade: notebook>=4.4.1 in /usr/local/lib/python3.7/dist-packages (from widgetsnbextension~=3.5.0->ipywidgets<8,>=7->tensorflow-model-analysis<0.28,>=0.27->tfx==0.27.0) (5.3.1)
# Requirement already satisfied, skipping upgrade: wcwidth in /usr/local/lib/python3.7/dist-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython<8,>=7->tensorflow-model-analysis<0.28,>=0.27->tfx==0.27.0) (0.2.5)
# Requirement already satisfied, skipping upgrade: parso<0.9.0,>=0.8.0 in /usr/local/lib/python3.7/dist-packages (from jedi>=0.16->ipython<8,>=7->tensorflow-model-analysis<0.28,>=0.27->tfx==0.27.0) (0.8.1)
# Requirement already satisfied, skipping upgrade: ptyprocess>=0.5 in /usr/local/lib/python3.7/dist-packages (from pexpect>4.3; sys_platform != "win32"->ipython<8,>=7->tensorflow-model-analysis<0.28,>=0.27->tfx==0.27.0) (0.7.0)
# Requirement already satisfied, skipping upgrade: typing-inspect>=0.4.0 in /usr/local/lib/python3.7/dist-packages (from libcst>=0.2.5->google-cloud-build<3,>=2.0.0; extra == "gcp"->apache-beam[gcp]<3,>=2.27->tfx==0.27.0) (0.6.0)
# Requirement already satisfied, skipping upgrade: pyzmq>=13 in /usr/local/lib/python3.7/dist-packages (from jupyter-client->ipykernel>=4.5.1->ipywidgets<8,>=7->tensorflow-model-analysis<0.28,>=0.27->tfx==0.27.0) (22.0.3)
# Requirement already satisfied, skipping upgrade: Send2Trash in /usr/local/lib/python3.7/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8,>=7->tensorflow-model-analysis<0.28,>=0.27->tfx==0.27.0) (1.5.0)
# Requirement already satisfied, skipping upgrade: terminado>=0.8.1 in /usr/local/lib/python3.7/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8,>=7->tensorflow-model-analysis<0.28,>=0.27->tfx==0.27.0) (0.9.2)
# Requirement already satisfied, skipping upgrade: nbconvert in /usr/local/lib/python3.7/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8,>=7->tensorflow-model-analysis<0.28,>=0.27->tfx==0.27.0) (5.6.1)
# Requirement already satisfied, skipping upgrade: mypy-extensions>=0.3.0 in /usr/local/lib/python3.7/dist-packages (from typing-inspect>=0.4.0->libcst>=0.2.5->google-cloud-build<3,>=2.0.0; extra == "gcp"->apache-beam[gcp]<3,>=2.27->tfx==0.27.0) (0.4.3)
# Requirement already satisfied, skipping upgrade: entrypoints>=0.2.2 in /usr/local/lib/python3.7/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8,>=7->tensorflow-model-analysis<0.28,>=0.27->tfx==0.27.0) (0.3)
# Requirement already satisfied, skipping upgrade: defusedxml in /usr/local/lib/python3.7/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8,>=7->tensorflow-model-analysis<0.28,>=0.27->tfx==0.27.0) (0.7.1)
# Requirement already satisfied, skipping upgrade: mistune<2,>=0.8.1 in /usr/local/lib/python3.7/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8,>=7->tensorflow-model-analysis<0.28,>=0.27->tfx==0.27.0) (0.8.4)
# Requirement already satisfied, skipping upgrade: pandocfilters>=1.4.1 in /usr/local/lib/python3.7/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8,>=7->tensorflow-model-analysis<0.28,>=0.27->tfx==0.27.0) (1.4.3)
# Requirement already satisfied, skipping upgrade: bleach in /usr/local/lib/python3.7/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8,>=7->tensorflow-model-analysis<0.28,>=0.27->tfx==0.27.0) (3.3.0)
# Requirement already satisfied, skipping upgrade: testpath in /usr/local/lib/python3.7/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8,>=7->tensorflow-model-analysis<0.28,>=0.27->tfx==0.27.0) (0.4.4)
# Requirement already satisfied, skipping upgrade: webencodings in /usr/local/lib/python3.7/dist-packages (from bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8,>=7->tensorflow-model-analysis<0.28,>=0.27->tfx==0.27.0) (0.5.1)

# %% [markdown]
# ### Import the packages

# %%
import logging
import os
import sys

import pandas as pd
import tensorflow as tf
from tfx.components import CsvExampleGen
from tfx.orchestration.experimental.interactive.interactive_context import InteractiveContext
from tfx.proto import example_gen_pb2

# %% [markdown]
# ## The dataset
#
# ### Download the dataset

# %%
# !mkdir data

# %%
import logging
import pandas as pd

# Initial dataset source
DATASET_URL = "http://bit.ly/building-ml-pipelines-dataset"

# Initial local dataset location
LOCAL_FILE_NAME = "data/consumer_complaints_with_narrative.csv"


def download_dataset(url=DATASET_URL):
    """download_dataset downloads the remote dataset to a local path

    Keyword Arguments:
        url {string} --
            complete url path to the csv data source (default: {DATASET_URL})
        local_path {string} --
            initial local file location (default: {LOCAL_FILE_NAME})
    Returns:
        None
    """
    df = pd.read_csv(url, index_col=0)
    df.to_csv(LOCAL_FILE_NAME)
    logging.info("Download completed.")


download_dataset()

# %% [markdown]
# ### Load the dataset

# %%
df = pd.read_csv(LOCAL_FILE_NAME)
df.head()
# Out:
#             product  ... consumer_disputed
# 0   Debt collection  ...                 0
# 1  Credit reporting  ...                 0
# 2   Debt collection  ...                 1
# 3          Mortgage  ...                 0
# 4      Student loan  ...                 1
#
# [5 rows x 11 columns]

# %% [markdown]
# ## Experiments
#
# ### First ingestion

# %%
context = InteractiveContext(pipeline_root='tfx')
# Out:
# WARNING:absl:InteractiveContext metadata_connection_config not provided: using SQLite ML Metadata database at tfx/metadata.sqlite.

# %%
data_dir = 'data'
example_gen = CsvExampleGen(input_base=data_dir)
context.run(example_gen)
# Out:
# WARNING:apache_beam.runners.interactive.interactive_environment:Dependencies required for Interactive Beam PCollection visualization are not available, please use: `pip install apache-beam[interactive]` to install necessary dependencies to enable all data visualization features.
# WARNING:apache_beam.io.tfrecordio:Couldn't find python-snappy so the implementation of _TFRecordUtil._masked_crc32c is not as fast as it could be.
# ExecutionResult(
#     component_id: CsvExampleGen
#     execution_id: 1
#     outputs:
#         examples: Channel(
#             type_name: Examples
#             artifacts: [Artifact(artifact: id: 1
#         type_id: 5
#         uri: "tfx/CsvExampleGen/examples/1"
#         properties {
#           key: "split_names"
#           value {
#             string_value: "[\"train\", \"eval\"]"
#           }
#         }
#         custom_properties {
#           key: "input_fingerprint"
#           value {
#             string_value: "split:single_split,num_files:1,total_bytes:78956236,xor_checksum:1616487535,sum_checksum:1616487535"
#           }
#         }
#         custom_properties {
#           key: "payload_format"
#           value {
#             string_value: "FORMAT_TF_EXAMPLE"
#           }
#         }
#         custom_properties {
#           key: "span"
#           value {
#             string_value: "0"
#           }
#         }
#         custom_properties {
#           key: "state"
#           value {
#             string_value: "published"
#           }
#         }
#         state: LIVE
#         , artifact_type: id: 5
#         name: "Examples"
#         properties {
#           key: "span"
#           value: INT
#         }
#         properties {
#           key: "split_names"
#           value: STRING
#         }
#         properties {
#           key: "version"
#           value: INT
#         }
#         )]
#             additional_properties: {}
#             additional_custom_properties: {}
#         ))

# %% [markdown]
# ### Split the dataset into subsets

# %%
output = example_gen_pb2.Output(
    split_config=example_gen_pb2.SplitConfig(splits=[
        example_gen_pb2.SplitConfig.Split(name='train', hash_buckets=6),
        example_gen_pb2.SplitConfig.Split(name='eval', hash_buckets=2),
        example_gen_pb2.SplitConfig.Split(name='test', hash_buckets=2)
    ]))

example_gen = CsvExampleGen(input_base=data_dir, output_config=output)

context.run(example_gen)
# Out:
# ExecutionResult(
#     component_id: CsvExampleGen
#     execution_id: 2
#     outputs:
#         examples: Channel(
#             type_name: Examples
#             artifacts: [Artifact(artifact: id: 2
#         type_id: 5
#         uri: "tfx/CsvExampleGen/examples/2"
#         properties {
#           key: "split_names"
#           value {
#             string_value: "[\"train\", \"eval\", \"test\"]"
#           }
#         }
#         custom_properties {
#           key: "input_fingerprint"
#           value {
#             string_value: "split:single_split,num_files:1,total_bytes:78956236,xor_checksum:1616487535,sum_checksum:1616487535"
#           }
#         }
#         custom_properties {
#           key: "payload_format"
#           value {
#             string_value: "FORMAT_TF_EXAMPLE"
#           }
#         }
#         custom_properties {
#           key: "span"
#           value {
#             string_value: "0"
#           }
#         }
#         custom_properties {
#           key: "state"
#           value {
#             string_value: "published"
#           }
#         }
#         state: LIVE
#         , artifact_type: id: 5
#         name: "Examples"
#         properties {
#           key: "span"
#           value: INT
#         }
#         properties {
#           key: "split_names"
#           value: STRING
#         }
#         properties {
#           key: "version"
#           value: INT
#         }
#         )]
#             additional_properties: {}
#             additional_custom_properties: {}
#         ))

# %% [markdown]
# ### Preserve existing splits

# %%
# !mkdir -p data/train
# !mkdir -p data/eval
# !mkdir -p data/test

# %%
df.iloc[:20000].to_csv('data/train/20k-consumer-complaints-training.csv', index=False)
df.iloc[20000:24000].to_csv('data/eval/4k-consumer-complaints-eval.csv', index=False)
df.iloc[24000:26000].to_csv('data/test/2k-consumer-complaints-test.csv', index=False)

# %%
input = example_gen_pb2.Input(splits=[
    example_gen_pb2.Input.Split(name='train', pattern='train/*'),
    example_gen_pb2.Input.Split(name='eval', pattern='eval/*'),
    example_gen_pb2.Input.Split(name='test', pattern='test/*')
])

example_gen = CsvExampleGen(input_base=data_dir, input_config=input)
context.run(example_gen)
# Out:
# ExecutionResult(
#     component_id: CsvExampleGen
#     execution_id: 3
#     outputs:
#         examples: Channel(
#             type_name: Examples
#             artifacts: [Artifact(artifact: id: 3
#         type_id: 5
#         uri: "tfx/CsvExampleGen/examples/3"
#         properties {
#           key: "split_names"
#           value {
#             string_value: "[\"train\", \"eval\", \"test\"]"
#           }
#         }
#         custom_properties {
#           key: "input_fingerprint"
#           value {
#             string_value: "split:train,num_files:1,total_bytes:23608185,xor_checksum:1616487600,sum_checksum:1616487600\nsplit:eval,num_files:1,total_bytes:4759360,xor_checksum:1616487601,sum_checksum:1616487601\nsplit:test,num_files:1,total_bytes:2428892,xor_checksum:1616487601,sum_checksum:1616487601"
#           }
#         }
#         custom_properties {
#           key: "payload_format"
#           value {
#             string_value: "FORMAT_TF_EXAMPLE"
#           }
#         }
#         custom_properties {
#           key: "span"
#           value {
#             string_value: "0"
#           }
#         }
#         custom_properties {
#           key: "state"
#           value {
#             string_value: "published"
#           }
#         }
#         state: LIVE
#         , artifact_type: id: 5
#         name: "Examples"
#         properties {
#           key: "span"
#           value: INT
#         }
#         properties {
#           key: "split_names"
#           value: STRING
#         }
#         properties {
#           key: "version"
#           value: INT
#         }
#         )]
#             additional_properties: {}
#             additional_custom_properties: {}
#         ))

# %% [markdown]
# ### Spanning Datasets

# %%
# !mkdir -p data/export-0
# !mkdir -p data/export-1
# !mkdir -p data/export-2

# %%
df.iloc[:20000].to_csv('data/export-0/20k-consumer-complaints.csv', index=False)
df.iloc[24000].to_csv('data/export-1/24k-consumer-complaints.csv', index=False)
df.iloc[26000].to_csv('data/export-2/26k-consumer-complaints.csv', index=False)

# %%
input = example_gen_pb2.Input(splits=[
    example_gen_pb2.Input.Split(pattern='export-{SPAN}/*')
])

example_gen = CsvExampleGen(input_base=data_dir, input_config=input)
context.run(example_gen)
# Out:
# ExecutionResult(
#     component_id: CsvExampleGen
#     execution_id: 4
#     outputs:
#         examples: Channel(
#             type_name: Examples
#             artifacts: [Artifact(artifact: id: 4
#         type_id: 5
#         uri: "tfx/CsvExampleGen/examples/4"
#         properties {
#           key: "split_names"
#           value {
#             string_value: "[\"train\", \"eval\"]"
#           }
#         }
#         custom_properties {
#           key: "input_fingerprint"
#           value {
#             string_value: "split:,num_files:1,total_bytes:412,xor_checksum:1616487615,sum_checksum:1616487615"
#           }
#         }
#         custom_properties {
#           key: "payload_format"
#           value {
#             string_value: "FORMAT_TF_EXAMPLE"
#           }
#         }
#         custom_properties {
#           key: "span"
#           value {
#             string_value: "2"
#           }
#         }
#         custom_properties {
#           key: "state"
#           value {
#             string_value: "published"
#           }
#         }
#         state: LIVE
#         , artifact_type: id: 5
#         name: "Examples"
#         properties {
#           key: "span"
#           value: INT
#         }
#         properties {
#           key: "split_names"
#           value: STRING
#         }
#         properties {
#           key: "version"
#           value: INT
#         }
#         )]
#             additional_properties: {}
#             additional_custom_properties: {}
#         ))
