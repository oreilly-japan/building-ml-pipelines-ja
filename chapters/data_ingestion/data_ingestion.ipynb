# %% [markdown]
# # Data Ingestion
#
# - パッケージインストール後はランタイムを再起動すること（Colab）

# %% [markdown]
# ## Setup

# %% [markdown]
# ### Install the packages

# %%
# !pip install -U tensorflow==2.4.1 tfx==0.27.0 pandas==1.2.3
# Out:
# Collecting tensorflow==2.4.1
#   Downloading tensorflow-2.4.1-cp37-cp37m-manylinux2010_x86_64.whl (394.3 MB)
#      |████████████████████████████████| 394.3 MB 14 kB/s
# Collecting tfx==0.27.0
#   Downloading tfx-0.27.0-py3-none-any.whl (2.3 MB)
#      |████████████████████████████████| 2.3 MB 39.0 MB/s
# Collecting pandas==1.2.3
#   Downloading pandas-1.2.3-cp37-cp37m-manylinux1_x86_64.whl (9.9 MB)
#      |████████████████████████████████| 9.9 MB 10.0 MB/s
# Requirement already satisfied: astunparse~=1.6.3 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.4.1) (1.6.3)
# Requirement already satisfied: absl-py~=0.10 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.4.1) (0.12.0)
# Collecting gast==0.3.3
#   Downloading gast-0.3.3-py2.py3-none-any.whl (9.7 kB)
# Requirement already satisfied: numpy~=1.19.2 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.4.1) (1.19.5)
# Requirement already satisfied: termcolor~=1.1.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.4.1) (1.1.0)
# Requirement already satisfied: six~=1.15.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.4.1) (1.15.0)
# Requirement already satisfied: typing-extensions~=3.7.4 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.4.1) (3.7.4.3)
# Collecting tensorflow-estimator<2.5.0,>=2.4.0
#   Downloading tensorflow_estimator-2.4.0-py2.py3-none-any.whl (462 kB)
#      |████████████████████████████████| 462 kB 37.5 MB/s
# Collecting grpcio~=1.32.0
#   Downloading grpcio-1.32.0-cp37-cp37m-manylinux2014_x86_64.whl (3.8 MB)
#      |████████████████████████████████| 3.8 MB 36.3 MB/s
# Requirement already satisfied: wheel~=0.35 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.4.1) (0.37.0)
# Collecting h5py~=2.10.0
#   Downloading h5py-2.10.0-cp37-cp37m-manylinux1_x86_64.whl (2.9 MB)
#      |████████████████████████████████| 2.9 MB 37.0 MB/s
# Requirement already satisfied: protobuf>=3.9.2 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.4.1) (3.17.3)
# Requirement already satisfied: opt-einsum~=3.3.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.4.1) (3.3.0)
# Requirement already satisfied: keras-preprocessing~=1.1.2 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.4.1) (1.1.2)
# Requirement already satisfied: flatbuffers~=1.12.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.4.1) (1.12)
# Requirement already satisfied: wrapt~=1.12.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.4.1) (1.12.1)
# Requirement already satisfied: google-pasta~=0.2 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.4.1) (0.2.0)
# Requirement already satisfied: tensorboard~=2.4 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.4.1) (2.5.0)
# Collecting keras-tuner<1.0.2,>=1
#   Downloading keras-tuner-1.0.1.tar.gz (54 kB)
#      |████████████████████████████████| 54 kB 2.4 MB/s
# Collecting tensorflow-transform<0.28,>=0.27
#   Downloading tensorflow_transform-0.27.0-py3-none-any.whl (386 kB)
#      |████████████████████████████████| 386 kB 34.7 MB/s
# Collecting tensorflow-hub<0.10,>=0.9.0
#   Downloading tensorflow_hub-0.9.0-py2.py3-none-any.whl (103 kB)
#      |████████████████████████████████| 103 kB 46.0 MB/s
# Collecting ml-metadata<0.28,>=0.27
#   Downloading ml_metadata-0.27.0-cp37-cp37m-manylinux2010_x86_64.whl (2.9 MB)
#      |████████████████████████████████| 2.9 MB 36.6 MB/s
# Collecting kubernetes<12,>=10.0.1
#   Downloading kubernetes-11.0.0-py3-none-any.whl (1.5 MB)
#      |████████████████████████████████| 1.5 MB 46.6 MB/s
# Collecting ml-pipelines-sdk==0.27.0
#   Downloading ml_pipelines_sdk-0.27.0-py3-none-any.whl (1.1 MB)
#      |████████████████████████████████| 1.1 MB 44.9 MB/s
# Collecting tensorflow-data-validation<0.28,>=0.27
#   Downloading tensorflow_data_validation-0.27.0-cp37-cp37m-manylinux2010_x86_64.whl (1.3 MB)
#      |████████████████████████████████| 1.3 MB 40.5 MB/s
# Requirement already satisfied: google-api-python-client<2,>=1.7.8 in /usr/local/lib/python3.7/dist-packages (from tfx==0.27.0) (1.12.8)
# Requirement already satisfied: jinja2<3,>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from tfx==0.27.0) (2.11.3)
# Collecting absl-py~=0.10
#   Downloading absl_py-0.10.0-py3-none-any.whl (127 kB)
#      |████████████████████████████████| 127 kB 61.3 MB/s
# Requirement already satisfied: click<8,>=7 in /usr/local/lib/python3.7/dist-packages (from tfx==0.27.0) (7.1.2)
# Collecting attrs<21,>=19.3.0
#   Downloading attrs-20.3.0-py2.py3-none-any.whl (49 kB)
#      |████████████████████████████████| 49 kB 6.1 MB/s
# Collecting tfx-bsl<0.28,>=0.27
#   Downloading tfx_bsl-0.27.1-cp37-cp37m-manylinux2010_x86_64.whl (2.2 MB)
#      |████████████████████████████████| 2.2 MB 37.0 MB/s
# Collecting pyarrow<3,>=1
#   Downloading pyarrow-2.0.0-cp37-cp37m-manylinux2014_x86_64.whl (17.7 MB)
#      |████████████████████████████████| 17.7 MB 73 kB/s
# Collecting tensorflow-serving-api!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,<3,>=1.15
#   Downloading tensorflow_serving_api-2.5.1-py2.py3-none-any.whl (38 kB)
# Collecting tensorflow-model-analysis<0.28,>=0.27
#   Downloading tensorflow_model_analysis-0.27.0-py3-none-any.whl (1.7 MB)
#      |████████████████████████████████| 1.7 MB 23.3 MB/s
# Requirement already satisfied: pyyaml<6,>=3.12 in /usr/local/lib/python3.7/dist-packages (from tfx==0.27.0) (3.13)
# Collecting apache-beam[gcp]<3,>=2.27
#   Downloading apache_beam-2.31.0-cp37-cp37m-manylinux2010_x86_64.whl (9.7 MB)
#      |████████████████████████████████| 9.7 MB 29.8 MB/s
# Collecting docker<5,>=4.1
#   Downloading docker-4.4.4-py2.py3-none-any.whl (147 kB)
#      |████████████████████████████████| 147 kB 60.2 MB/s
# Collecting tensorflow-cloud<0.2,>=0.1
#   Downloading tensorflow_cloud-0.1.16-py3-none-any.whl (92 kB)
#      |████████████████████████████████| 92 kB 564 kB/s
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas==1.2.3) (2018.9)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas==1.2.3) (2.8.2)
# Collecting requests<3.0.0,>=2.24.0
#   Downloading requests-2.26.0-py2.py3-none-any.whl (62 kB)
#      |████████████████████████████████| 62 kB 857 kB/s
# Requirement already satisfied: oauth2client<5,>=2.0.1 in /usr/local/lib/python3.7/dist-packages (from apache-beam[gcp]<3,>=2.27->tfx==0.27.0) (4.1.3)
# Requirement already satisfied: pymongo<4.0.0,>=3.8.0 in /usr/local/lib/python3.7/dist-packages (from apache-beam[gcp]<3,>=2.27->tfx==0.27.0) (3.12.0)
# Requirement already satisfied: crcmod<2.0,>=1.7 in /usr/local/lib/python3.7/dist-packages (from apache-beam[gcp]<3,>=2.27->tfx==0.27.0) (1.7)
# Collecting dill<0.3.2,>=0.3.1.1
#   Downloading dill-0.3.1.1.tar.gz (151 kB)
#      |████████████████████████████████| 151 kB 53.8 MB/s
# Collecting fastavro<2,>=0.21.4
#   Downloading fastavro-1.4.4-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.3 MB)
#      |████████████████████████████████| 2.3 MB 39.2 MB/s
# Collecting hdfs<3.0.0,>=2.1.0
#   Downloading hdfs-2.6.0-py3-none-any.whl (33 kB)
# Collecting avro-python3!=1.9.2,<1.10.0,>=1.8.1
#   Downloading avro-python3-1.9.2.1.tar.gz (37 kB)
# Requirement already satisfied: pydot<2,>=1.2.0 in /usr/local/lib/python3.7/dist-packages (from apache-beam[gcp]<3,>=2.27->tfx==0.27.0) (1.3.0)
# Requirement already satisfied: httplib2<0.20.0,>=0.8 in /usr/local/lib/python3.7/dist-packages (from apache-beam[gcp]<3,>=2.27->tfx==0.27.0) (0.17.4)
# Collecting future<1.0.0,>=0.18.2
#   Downloading future-0.18.2.tar.gz (829 kB)
#      |████████████████████████████████| 829 kB 54.3 MB/s
# Collecting google-cloud-dlp<2,>=0.12.0
#   Downloading google_cloud_dlp-1.0.0-py2.py3-none-any.whl (169 kB)
#      |████████████████████████████████| 169 kB 48.9 MB/s
# Requirement already satisfied: google-cloud-core<2,>=0.28.1 in /usr/local/lib/python3.7/dist-packages (from apache-beam[gcp]<3,>=2.27->tfx==0.27.0) (1.0.3)
# Collecting google-cloud-bigtable<2,>=0.31.1
#   Downloading google_cloud_bigtable-1.7.0-py2.py3-none-any.whl (267 kB)
#      |████████████████████████████████| 267 kB 51.0 MB/s
# Collecting google-cloud-language<2,>=1.3.0
#   Downloading google_cloud_language-1.3.0-py2.py3-none-any.whl (83 kB)
#      |████████████████████████████████| 83 kB 1.9 MB/s
# Collecting google-cloud-pubsub<2,>=0.39.0
#   Downloading google_cloud_pubsub-1.7.0-py2.py3-none-any.whl (144 kB)
#      |████████████████████████████████| 144 kB 50.3 MB/s
# Collecting google-apitools<0.5.32,>=0.5.31
#   Downloading google-apitools-0.5.31.tar.gz (173 kB)
#      |████████████████████████████████| 173 kB 46.8 MB/s
# Requirement already satisfied: cachetools<5,>=3.1.0 in /usr/local/lib/python3.7/dist-packages (from apache-beam[gcp]<3,>=2.27->tfx==0.27.0) (4.2.2)
# Collecting google-cloud-vision<2,>=0.38.0
#   Downloading google_cloud_vision-1.0.0-py2.py3-none-any.whl (435 kB)
#      |████████████████████████████████| 435 kB 51.0 MB/s
# Requirement already satisfied: google-cloud-bigquery<3,>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from apache-beam[gcp]<3,>=2.27->tfx==0.27.0) (1.21.0)
# Requirement already satisfied: google-cloud-datastore<2,>=1.7.1 in /usr/local/lib/python3.7/dist-packages (from apache-beam[gcp]<3,>=2.27->tfx==0.27.0) (1.8.0)
# Collecting grpcio-gcp<1,>=0.2.2
#   Downloading grpcio_gcp-0.2.2-py2.py3-none-any.whl (9.4 kB)
# Requirement already satisfied: google-auth<2,>=1.18.0 in /usr/local/lib/python3.7/dist-packages (from apache-beam[gcp]<3,>=2.27->tfx==0.27.0) (1.34.0)
# Collecting google-cloud-spanner<2,>=1.13.0
#   Downloading google_cloud_spanner-1.19.1-py2.py3-none-any.whl (255 kB)
#      |████████████████████████████████| 255 kB 60.8 MB/s
# Collecting google-cloud-profiler<4,>=3.0.4
#   Downloading google-cloud-profiler-3.0.5.tar.gz (34 kB)
# Collecting google-cloud-videointelligence<2,>=1.8.0
#   Downloading google_cloud_videointelligence-1.16.1-py2.py3-none-any.whl (183 kB)
#      |████████████████████████████████| 183 kB 50.7 MB/s
# Collecting websocket-client>=0.32.0
#   Downloading websocket_client-1.2.1-py2.py3-none-any.whl (52 kB)
#      |████████████████████████████████| 52 kB 1.6 MB/s
# Requirement already satisfied: google-auth-httplib2>=0.0.3 in /usr/local/lib/python3.7/dist-packages (from google-api-python-client<2,>=1.7.8->tfx==0.27.0) (0.0.4)
# Requirement already satisfied: google-api-core<2dev,>=1.21.0 in /usr/local/lib/python3.7/dist-packages (from google-api-python-client<2,>=1.7.8->tfx==0.27.0) (1.26.3)
# Requirement already satisfied: uritemplate<4dev,>=3.0.0 in /usr/local/lib/python3.7/dist-packages (from google-api-python-client<2,>=1.7.8->tfx==0.27.0) (3.0.1)
# Requirement already satisfied: setuptools>=40.3.0 in /usr/local/lib/python3.7/dist-packages (from google-api-core<2dev,>=1.21.0->google-api-python-client<2,>=1.7.8->tfx==0.27.0) (57.2.0)
# Requirement already satisfied: packaging>=14.3 in /usr/local/lib/python3.7/dist-packages (from google-api-core<2dev,>=1.21.0->google-api-python-client<2,>=1.7.8->tfx==0.27.0) (21.0)
# Requirement already satisfied: googleapis-common-protos<2.0dev,>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from google-api-core<2dev,>=1.21.0->google-api-python-client<2,>=1.7.8->tfx==0.27.0) (1.53.0)
# Collecting fasteners>=0.14
#   Downloading fasteners-0.16.3-py2.py3-none-any.whl (28 kB)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.7/dist-packages (from google-auth<2,>=1.18.0->apache-beam[gcp]<3,>=2.27->tfx==0.27.0) (4.7.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.7/dist-packages (from google-auth<2,>=1.18.0->apache-beam[gcp]<3,>=2.27->tfx==0.27.0) (0.2.8)
# Requirement already satisfied: google-resumable-media!=0.4.0,<0.5.0dev,>=0.3.1 in /usr/local/lib/python3.7/dist-packages (from google-cloud-bigquery<3,>=1.6.0->apache-beam[gcp]<3,>=2.27->tfx==0.27.0) (0.4.1)
# Collecting grpc-google-iam-v1<0.13dev,>=0.12.3
#   Downloading grpc-google-iam-v1-0.12.3.tar.gz (13 kB)
# Collecting google-cloud-core<2,>=0.28.1
#   Downloading google_cloud_core-1.7.2-py2.py3-none-any.whl (28 kB)
# Requirement already satisfied: docopt in /usr/local/lib/python3.7/dist-packages (from hdfs<3.0.0,>=2.1.0->apache-beam[gcp]<3,>=2.27->tfx==0.27.0) (0.6.2)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.7/dist-packages (from jinja2<3,>=2.7.3->tfx==0.27.0) (2.0.1)
# Requirement already satisfied: tabulate in /usr/local/lib/python3.7/dist-packages (from keras-tuner<1.0.2,>=1->tfx==0.27.0) (0.8.9)
# Collecting terminaltables
#   Downloading terminaltables-3.1.0.tar.gz (12 kB)
# Collecting colorama
#   Downloading colorama-0.4.4-py2.py3-none-any.whl (16 kB)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from keras-tuner<1.0.2,>=1->tfx==0.27.0) (4.62.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.7/dist-packages (from keras-tuner<1.0.2,>=1->tfx==0.27.0) (1.4.1)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.7/dist-packages (from keras-tuner<1.0.2,>=1->tfx==0.27.0) (0.22.2.post1)
# Requirement already satisfied: urllib3>=1.24.2 in /usr/local/lib/python3.7/dist-packages (from kubernetes<12,>=10.0.1->tfx==0.27.0) (1.24.3)
# Requirement already satisfied: requests-oauthlib in /usr/local/lib/python3.7/dist-packages (from kubernetes<12,>=10.0.1->tfx==0.27.0) (1.3.0)
# Requirement already satisfied: certifi>=14.05.14 in /usr/local/lib/python3.7/dist-packages (from kubernetes<12,>=10.0.1->tfx==0.27.0) (2021.5.30)
# Requirement already satisfied: pyasn1>=0.1.7 in /usr/local/lib/python3.7/dist-packages (from oauth2client<5,>=2.0.1->apache-beam[gcp]<3,>=2.27->tfx==0.27.0) (0.4.8)
# Requirement already satisfied: pyparsing>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=14.3->google-api-core<2dev,>=1.21.0->google-api-python-client<2,>=1.7.8->tfx==0.27.0) (2.4.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.24.0->apache-beam[gcp]<3,>=2.27->tfx==0.27.0) (2.10)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.24.0->apache-beam[gcp]<3,>=2.27->tfx==0.27.0) (2.0.4)
# Requirement already satisfied: werkzeug>=0.11.15 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.4->tensorflow==2.4.1) (1.0.1)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.4->tensorflow==2.4.1) (3.3.4)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.4->tensorflow==2.4.1) (0.6.1)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.4->tensorflow==2.4.1) (1.8.0)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.4->tensorflow==2.4.1) (0.4.5)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from markdown>=2.6.8->tensorboard~=2.4->tensorflow==2.4.1) (4.6.3)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.7/dist-packages (from requests-oauthlib->kubernetes<12,>=10.0.1->tfx==0.27.0) (3.1.1)
# Requirement already satisfied: tensorflow-datasets in /usr/local/lib/python3.7/dist-packages (from tensorflow-cloud<0.2,>=0.1->tfx==0.27.0) (4.0.1)
# Requirement already satisfied: google-cloud-storage in /usr/local/lib/python3.7/dist-packages (from tensorflow-cloud<0.2,>=0.1->tfx==0.27.0) (1.18.1)
# Collecting joblib<0.15,>=0.12
#   Downloading joblib-0.14.1-py2.py3-none-any.whl (294 kB)
#      |████████████████████████████████| 294 kB 53.4 MB/s
# Collecting tensorflow-metadata<0.28,>=0.27
#   Downloading tensorflow_metadata-0.27.0-py3-none-any.whl (47 kB)
#      |████████████████████████████████| 47 kB 4.4 MB/s
# Collecting ipython<8,>=7
#   Downloading ipython-7.26.0-py3-none-any.whl (786 kB)
#      |████████████████████████████████| 786 kB 30.4 MB/s
# Requirement already satisfied: ipywidgets<8,>=7 in /usr/local/lib/python3.7/dist-packages (from tensorflow-model-analysis<0.28,>=0.27->tfx==0.27.0) (7.6.3)
# Requirement already satisfied: pygments in /usr/local/lib/python3.7/dist-packages (from ipython<8,>=7->tensorflow-model-analysis<0.28,>=0.27->tfx==0.27.0) (2.6.1)
# Requirement already satisfied: decorator in /usr/local/lib/python3.7/dist-packages (from ipython<8,>=7->tensorflow-model-analysis<0.28,>=0.27->tfx==0.27.0) (4.4.2)
# Requirement already satisfied: matplotlib-inline in /usr/local/lib/python3.7/dist-packages (from ipython<8,>=7->tensorflow-model-analysis<0.28,>=0.27->tfx==0.27.0) (0.1.2)
# Requirement already satisfied: backcall in /usr/local/lib/python3.7/dist-packages (from ipython<8,>=7->tensorflow-model-analysis<0.28,>=0.27->tfx==0.27.0) (0.2.0)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.7/dist-packages (from ipython<8,>=7->tensorflow-model-analysis<0.28,>=0.27->tfx==0.27.0) (0.7.5)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.7/dist-packages (from ipython<8,>=7->tensorflow-model-analysis<0.28,>=0.27->tfx==0.27.0) (4.8.0)
# Collecting prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0
#   Downloading prompt_toolkit-3.0.19-py3-none-any.whl (368 kB)
#      |████████████████████████████████| 368 kB 44.6 MB/s
# Requirement already satisfied: jedi>=0.16 in /usr/local/lib/python3.7/dist-packages (from ipython<8,>=7->tensorflow-model-analysis<0.28,>=0.27->tfx==0.27.0) (0.18.0)
# Requirement already satisfied: traitlets>=4.2 in /usr/local/lib/python3.7/dist-packages (from ipython<8,>=7->tensorflow-model-analysis<0.28,>=0.27->tfx==0.27.0) (5.0.5)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in /usr/local/lib/python3.7/dist-packages (from ipywidgets<8,>=7->tensorflow-model-analysis<0.28,>=0.27->tfx==0.27.0) (1.0.0)
# Requirement already satisfied: nbformat>=4.2.0 in /usr/local/lib/python3.7/dist-packages (from ipywidgets<8,>=7->tensorflow-model-analysis<0.28,>=0.27->tfx==0.27.0) (5.1.3)
# Requirement already satisfied: widgetsnbextension~=3.5.0 in /usr/local/lib/python3.7/dist-packages (from ipywidgets<8,>=7->tensorflow-model-analysis<0.28,>=0.27->tfx==0.27.0) (3.5.1)
# Requirement already satisfied: ipykernel>=4.5.1 in /usr/local/lib/python3.7/dist-packages (from ipywidgets<8,>=7->tensorflow-model-analysis<0.28,>=0.27->tfx==0.27.0) (4.10.1)
# Requirement already satisfied: tornado>=4.0 in /usr/local/lib/python3.7/dist-packages (from ipykernel>=4.5.1->ipywidgets<8,>=7->tensorflow-model-analysis<0.28,>=0.27->tfx==0.27.0) (5.1.1)
# Requirement already satisfied: jupyter-client in /usr/local/lib/python3.7/dist-packages (from ipykernel>=4.5.1->ipywidgets<8,>=7->tensorflow-model-analysis<0.28,>=0.27->tfx==0.27.0) (5.3.5)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /usr/local/lib/python3.7/dist-packages (from jedi>=0.16->ipython<8,>=7->tensorflow-model-analysis<0.28,>=0.27->tfx==0.27.0) (0.8.2)
# Requirement already satisfied: jsonschema!=2.5.0,>=2.4 in /usr/local/lib/python3.7/dist-packages (from nbformat>=4.2.0->ipywidgets<8,>=7->tensorflow-model-analysis<0.28,>=0.27->tfx==0.27.0) (2.6.0)
# Requirement already satisfied: jupyter-core in /usr/local/lib/python3.7/dist-packages (from nbformat>=4.2.0->ipywidgets<8,>=7->tensorflow-model-analysis<0.28,>=0.27->tfx==0.27.0) (4.7.1)
# Requirement already satisfied: ipython-genutils in /usr/local/lib/python3.7/dist-packages (from nbformat>=4.2.0->ipywidgets<8,>=7->tensorflow-model-analysis<0.28,>=0.27->tfx==0.27.0) (0.2.0)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.7/dist-packages (from pexpect>4.3->ipython<8,>=7->tensorflow-model-analysis<0.28,>=0.27->tfx==0.27.0) (0.7.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.7/dist-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython<8,>=7->tensorflow-model-analysis<0.28,>=0.27->tfx==0.27.0) (0.2.5)
# Collecting tensorflow-serving-api!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,<3,>=1.15
#   Downloading tensorflow_serving_api-2.4.2-py2.py3-none-any.whl (38 kB)
#   Downloading tensorflow_serving_api-2.4.1-py2.py3-none-any.whl (38 kB)
# Requirement already satisfied: notebook>=4.4.1 in /usr/local/lib/python3.7/dist-packages (from widgetsnbextension~=3.5.0->ipywidgets<8,>=7->tensorflow-model-analysis<0.28,>=0.27->tfx==0.27.0) (5.3.1)
# Requirement already satisfied: terminado>=0.8.1 in /usr/local/lib/python3.7/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8,>=7->tensorflow-model-analysis<0.28,>=0.27->tfx==0.27.0) (0.10.1)
# Requirement already satisfied: nbconvert in /usr/local/lib/python3.7/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8,>=7->tensorflow-model-analysis<0.28,>=0.27->tfx==0.27.0) (5.6.1)
# Requirement already satisfied: Send2Trash in /usr/local/lib/python3.7/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8,>=7->tensorflow-model-analysis<0.28,>=0.27->tfx==0.27.0) (1.8.0)
# Requirement already satisfied: pyzmq>=13 in /usr/local/lib/python3.7/dist-packages (from jupyter-client->ipykernel>=4.5.1->ipywidgets<8,>=7->tensorflow-model-analysis<0.28,>=0.27->tfx==0.27.0) (22.2.1)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->markdown>=2.6.8->tensorboard~=2.4->tensorflow==2.4.1) (3.5.0)
# Requirement already satisfied: mistune<2,>=0.8.1 in /usr/local/lib/python3.7/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8,>=7->tensorflow-model-analysis<0.28,>=0.27->tfx==0.27.0) (0.8.4)
# Requirement already satisfied: pandocfilters>=1.4.1 in /usr/local/lib/python3.7/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8,>=7->tensorflow-model-analysis<0.28,>=0.27->tfx==0.27.0) (1.4.3)
# Requirement already satisfied: defusedxml in /usr/local/lib/python3.7/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8,>=7->tensorflow-model-analysis<0.28,>=0.27->tfx==0.27.0) (0.7.1)
# Requirement already satisfied: entrypoints>=0.2.2 in /usr/local/lib/python3.7/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8,>=7->tensorflow-model-analysis<0.28,>=0.27->tfx==0.27.0) (0.3)
# Requirement already satisfied: bleach in /usr/local/lib/python3.7/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8,>=7->tensorflow-model-analysis<0.28,>=0.27->tfx==0.27.0) (4.0.0)
# Requirement already satisfied: testpath in /usr/local/lib/python3.7/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8,>=7->tensorflow-model-analysis<0.28,>=0.27->tfx==0.27.0) (0.5.0)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.7/dist-packages (from bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8,>=7->tensorflow-model-analysis<0.28,>=0.27->tfx==0.27.0) (0.5.1)
# Requirement already satisfied: promise in /usr/local/lib/python3.7/dist-packages (from tensorflow-datasets->tensorflow-cloud<0.2,>=0.1->tfx==0.27.0) (2.3)
# Requirement already satisfied: dm-tree in /usr/local/lib/python3.7/dist-packages (from tensorflow-datasets->tensorflow-cloud<0.2,>=0.1->tfx==0.27.0) (0.1.6)
# Requirement already satisfied: importlib-resources in /usr/local/lib/python3.7/dist-packages (from tensorflow-datasets->tensorflow-cloud<0.2,>=0.1->tfx==0.27.0) (5.2.2)
# Building wheels for collected packages: avro-python3, dill, future, google-apitools, google-cloud-profiler, grpc-google-iam-v1, keras-tuner, terminaltables
#   Building wheel for avro-python3 (setup.py) ... done
#   Created wheel for avro-python3: filename=avro_python3-1.9.2.1-py3-none-any.whl size=43512 sha256=be3cbbee7ce44866d361aa33c9d527bfa925adda7bc0f38de6be153fa35f622f
#   Stored in directory: /root/.cache/pip/wheels/bc/49/5f/fdb5b9d85055c478213e0158ac122b596816149a02d82e0ab1
#   Building wheel for dill (setup.py) ... done
#   Created wheel for dill: filename=dill-0.3.1.1-py3-none-any.whl size=78546 sha256=164340e4eaafa2b77711cd09173cf07b0ae085a9c98fe1e53e12041431c635da
#   Stored in directory: /root/.cache/pip/wheels/a4/61/fd/c57e374e580aa78a45ed78d5859b3a44436af17e22ca53284f
#   Building wheel for future (setup.py) ... done
#   Created wheel for future: filename=future-0.18.2-py3-none-any.whl size=491070 sha256=18227f1112b820b9511a953ef7204a39522e05f77435a9f31d93ffcaad6b76ca
#   Stored in directory: /root/.cache/pip/wheels/56/b0/fe/4410d17b32f1f0c3cf54cdfb2bc04d7b4b8f4ae377e2229ba0
#   Building wheel for google-apitools (setup.py) ... done
#   Created wheel for google-apitools: filename=google_apitools-0.5.31-py3-none-any.whl size=131040 sha256=d290a0bea44bc2b2fa0587ca07827f651728410018b156ef165c2cb53e3498a9
#   Stored in directory: /root/.cache/pip/wheels/19/b5/2f/1cc3cf2b31e7a9cd1508731212526d9550271274d351c96f16
#   Building wheel for google-cloud-profiler (setup.py) ... done
#   Created wheel for google-cloud-profiler: filename=google_cloud_profiler-3.0.5-cp37-cp37m-linux_x86_64.whl size=703454 sha256=b8da4a22c5182d51b1e9d004654fd48acf41dc3589a83820e51be45898fbc60b
#   Stored in directory: /root/.cache/pip/wheels/9f/24/e7/54a8a406d778d2d81aafc6d45b6cc9cca479373d2037f9102a
#   Building wheel for grpc-google-iam-v1 (setup.py) ... done
#   Created wheel for grpc-google-iam-v1: filename=grpc_google_iam_v1-0.12.3-py3-none-any.whl size=18515 sha256=04085f856e1dd094e1c66e65ec5fd6d2fe6ae68711d108df30253bb2ef6fac65
#   Stored in directory: /root/.cache/pip/wheels/b9/ee/67/2e444183030cb8d31ce8b34cee34a7afdbd3ba5959ea846380
#   Building wheel for keras-tuner (setup.py) ... done
#   Created wheel for keras-tuner: filename=keras_tuner-1.0.1-py3-none-any.whl size=73198 sha256=7c7240d8a82fd362456af1b10716c34b16bf1ba05606622dca1e5004fa78e17b
#   Stored in directory: /root/.cache/pip/wheels/0b/cf/2f/1a1749d3a3650fac3305a8d7f9237b6de7c41068e2f8520ca2
#   Building wheel for terminaltables (setup.py) ... done
#   Created wheel for terminaltables: filename=terminaltables-3.1.0-py3-none-any.whl size=15354 sha256=3c2e1624e36717731a63951488cc8e7e9488edd2ca2373a069fa4b0e04ea41b9
#   Stored in directory: /root/.cache/pip/wheels/ba/ad/c8/2d98360791161cd3db6daf6b5e730f34021fc9367d5879f497
# Successfully built avro-python3 dill future google-apitools google-cloud-profiler grpc-google-iam-v1 keras-tuner terminaltables
# Installing collected packages: requests, grpcio, prompt-toolkit, grpcio-gcp, absl-py, tensorflow-estimator, pyarrow, ipython, hdfs, h5py, grpc-google-iam-v1, google-cloud-core, gast, future, fasteners, fastavro, dill, avro-python3, tensorflow, google-cloud-vision, google-cloud-videointelligence, google-cloud-spanner, google-cloud-pubsub, google-cloud-profiler, google-cloud-language, google-cloud-dlp, google-cloud-bigtable, google-apitools, apache-beam, tensorflow-serving-api, tensorflow-metadata, pandas, joblib, websocket-client, tfx-bsl, terminaltables, colorama, attrs, tensorflow-transform, ml-metadata, keras-tuner, docker, tensorflow-model-analysis, tensorflow-hub, tensorflow-data-validation, tensorflow-cloud, ml-pipelines-sdk, kubernetes, tfx
#   Attempting uninstall: requests
#     Found existing installation: requests 2.23.0
#     Uninstalling requests-2.23.0:
#       Successfully uninstalled requests-2.23.0
#   Attempting uninstall: grpcio
#     Found existing installation: grpcio 1.34.1
#     Uninstalling grpcio-1.34.1:
#       Successfully uninstalled grpcio-1.34.1
#   Attempting uninstall: prompt-toolkit
#     Found existing installation: prompt-toolkit 1.0.18
#     Uninstalling prompt-toolkit-1.0.18:
#       Successfully uninstalled prompt-toolkit-1.0.18
#   Attempting uninstall: absl-py
#     Found existing installation: absl-py 0.12.0
#     Uninstalling absl-py-0.12.0:
#       Successfully uninstalled absl-py-0.12.0
#   Attempting uninstall: tensorflow-estimator
#     Found existing installation: tensorflow-estimator 2.5.0
#     Uninstalling tensorflow-estimator-2.5.0:
#       Successfully uninstalled tensorflow-estimator-2.5.0
#   Attempting uninstall: pyarrow
#     Found existing installation: pyarrow 3.0.0
#     Uninstalling pyarrow-3.0.0:
#       Successfully uninstalled pyarrow-3.0.0
#   Attempting uninstall: ipython
#     Found existing installation: ipython 5.5.0
#     Uninstalling ipython-5.5.0:
#       Successfully uninstalled ipython-5.5.0
#   Attempting uninstall: h5py
#     Found existing installation: h5py 3.1.0
#     Uninstalling h5py-3.1.0:
#       Successfully uninstalled h5py-3.1.0
#   Attempting uninstall: google-cloud-core
#     Found existing installation: google-cloud-core 1.0.3
#     Uninstalling google-cloud-core-1.0.3:
#       Successfully uninstalled google-cloud-core-1.0.3
#   Attempting uninstall: gast
#     Found existing installation: gast 0.4.0
#     Uninstalling gast-0.4.0:
#       Successfully uninstalled gast-0.4.0
#   Attempting uninstall: future
#     Found existing installation: future 0.16.0
#     Uninstalling future-0.16.0:
#       Successfully uninstalled future-0.16.0
#   Attempting uninstall: dill
#     Found existing installation: dill 0.3.4
#     Uninstalling dill-0.3.4:
#       Successfully uninstalled dill-0.3.4
#   Attempting uninstall: tensorflow
#     Found existing installation: tensorflow 2.5.0
#     Uninstalling tensorflow-2.5.0:
#       Successfully uninstalled tensorflow-2.5.0
#   Attempting uninstall: google-cloud-language
#     Found existing installation: google-cloud-language 1.2.0
#     Uninstalling google-cloud-language-1.2.0:
#       Successfully uninstalled google-cloud-language-1.2.0
#   Attempting uninstall: tensorflow-metadata
#     Found existing installation: tensorflow-metadata 1.2.0
#     Uninstalling tensorflow-metadata-1.2.0:
#       Successfully uninstalled tensorflow-metadata-1.2.0
#   Attempting uninstall: pandas
#     Found existing installation: pandas 1.1.5
#     Uninstalling pandas-1.1.5:
#       Successfully uninstalled pandas-1.1.5
#   Attempting uninstall: joblib
#     Found existing installation: joblib 1.0.1
#     Uninstalling joblib-1.0.1:
#       Successfully uninstalled joblib-1.0.1
#   Attempting uninstall: attrs
#     Found existing installation: attrs 21.2.0
#     Uninstalling attrs-21.2.0:
#       Successfully uninstalled attrs-21.2.0
#   Attempting uninstall: tensorflow-hub
#     Found existing installation: tensorflow-hub 0.12.0
#     Uninstalling tensorflow-hub-0.12.0:
#       Successfully uninstalled tensorflow-hub-0.12.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# multiprocess 0.70.12.2 requires dill>=0.3.4, but you have dill 0.3.1.1 which is incompatible.
# jupyter-console 5.2.0 requires prompt-toolkit<2.0.0,>=1.0.0, but you have prompt-toolkit 3.0.19 which is incompatible.
# google-colab 1.0.0 requires ipython~=5.5.0, but you have ipython 7.26.0 which is incompatible.
# google-colab 1.0.0 requires pandas~=1.1.0; python_version >= "3.0", but you have pandas 1.2.3 which is incompatible.
# google-colab 1.0.0 requires requests~=2.23.0, but you have requests 2.26.0 which is incompatible.
# datascience 0.10.6 requires folium==0.2.1, but you have folium 0.8.3 which is incompatible.
# Successfully installed absl-py-0.10.0 apache-beam-2.31.0 attrs-20.3.0 avro-python3-1.9.2.1 colorama-0.4.4 dill-0.3.1.1 docker-4.4.4 fastavro-1.4.4 fasteners-0.16.3 future-0.18.2 gast-0.3.3 google-apitools-0.5.31 google-cloud-bigtable-1.7.0 google-cloud-core-1.7.2 google-cloud-dlp-1.0.0 google-cloud-language-1.3.0 google-cloud-profiler-3.0.5 google-cloud-pubsub-1.7.0 google-cloud-spanner-1.19.1 google-cloud-videointelligence-1.16.1 google-cloud-vision-1.0.0 grpc-google-iam-v1-0.12.3 grpcio-1.32.0 grpcio-gcp-0.2.2 h5py-2.10.0 hdfs-2.6.0 ipython-7.26.0 joblib-0.14.1 keras-tuner-1.0.1 kubernetes-11.0.0 ml-metadata-0.27.0 ml-pipelines-sdk-0.27.0 pandas-1.2.3 prompt-toolkit-3.0.19 pyarrow-2.0.0 requests-2.26.0 tensorflow-2.4.1 tensorflow-cloud-0.1.16 tensorflow-data-validation-0.27.0 tensorflow-estimator-2.4.0 tensorflow-hub-0.9.0 tensorflow-metadata-0.27.0 tensorflow-model-analysis-0.27.0 tensorflow-serving-api-2.4.1 tensorflow-transform-0.27.0 terminaltables-3.1.0 tfx-0.27.0 tfx-bsl-0.27.1 websocket-client-1.2.1

# %% [markdown]
# ### Import the packages

# %%
import logging
import os
import sys

import pandas as pd
import tensorflow as tf
from tfx.components import CsvExampleGen
from tfx.orchestration.experimental.interactive.interactive_context import InteractiveContext
from tfx.proto import example_gen_pb2

# %% [markdown]
# ## The dataset
#
# ### Download the dataset

# %%
# !mkdir data

# %%
import logging
import pandas as pd

# Initial dataset source
DATASET_URL = "http://bit.ly/building-ml-pipelines-dataset"

# Initial local dataset location
LOCAL_FILE_NAME = "data/consumer_complaints_with_narrative.csv"


def download_dataset(url=DATASET_URL):
    """download_dataset downloads the remote dataset to a local path

    Keyword Arguments:
        url {string} --
            complete url path to the csv data source (default: {DATASET_URL})
        local_path {string} --
            initial local file location (default: {LOCAL_FILE_NAME})
    Returns:
        None
    """
    df = pd.read_csv(url, index_col=0)
    df.to_csv(LOCAL_FILE_NAME)
    logging.info("Download completed.")


download_dataset()

# %% [markdown]
# ### Load the dataset

# %%
df = pd.read_csv(LOCAL_FILE_NAME)
df.head()
# Out:
#             product  ... consumer_disputed
# 0   Debt collection  ...                 0
# 1  Credit reporting  ...                 0
# 2   Debt collection  ...                 1
# 3          Mortgage  ...                 0
# 4      Student loan  ...                 1
#
# [5 rows x 11 columns]

# %% [markdown]
# ## Experiments
#
# ### First ingestion

# %%
context = InteractiveContext(pipeline_root='tfx')
# Out:
# WARNING:absl:InteractiveContext metadata_connection_config not provided: using SQLite ML Metadata database at tfx/metadata.sqlite.

# %%
data_dir = 'data'
example_gen = CsvExampleGen(input_base=data_dir)
context.run(example_gen)
# Out:
# WARNING:root:Make sure that locally built Python SDK docker image has Python 3.7 interpreter.
# WARNING:apache_beam.runners.interactive.interactive_environment:Dependencies required for Interactive Beam PCollection visualization are not available, please use: `pip install apache-beam[interactive]` to install necessary dependencies to enable all data visualization features.
# WARNING:apache_beam.io.tfrecordio:Couldn't find python-snappy so the implementation of _TFRecordUtil._masked_crc32c is not as fast as it could be.
# ExecutionResult(
#     component_id: CsvExampleGen
#     execution_id: 1
#     outputs:
#         examples: Channel(
#             type_name: Examples
#             artifacts: [Artifact(artifact: id: 1
#         type_id: 5
#         uri: "tfx/CsvExampleGen/examples/1"
#         properties {
#           key: "split_names"
#           value {
#             string_value: "[\"train\", \"eval\"]"
#           }
#         }
#         custom_properties {
#           key: "input_fingerprint"
#           value {
#             string_value: "split:single_split,num_files:1,total_bytes:78956236,xor_checksum:1629119443,sum_checksum:1629119443"
#           }
#         }
#         custom_properties {
#           key: "payload_format"
#           value {
#             string_value: "FORMAT_TF_EXAMPLE"
#           }
#         }
#         custom_properties {
#           key: "span"
#           value {
#             string_value: "0"
#           }
#         }
#         custom_properties {
#           key: "state"
#           value {
#             string_value: "published"
#           }
#         }
#         state: LIVE
#         , artifact_type: id: 5
#         name: "Examples"
#         properties {
#           key: "span"
#           value: INT
#         }
#         properties {
#           key: "split_names"
#           value: STRING
#         }
#         properties {
#           key: "version"
#           value: INT
#         }
#         )]
#             additional_properties: {}
#             additional_custom_properties: {}
#         ))

# %% [markdown]
# ### Split the dataset into subsets

# %%
output = example_gen_pb2.Output(
    split_config=example_gen_pb2.SplitConfig(splits=[
        example_gen_pb2.SplitConfig.Split(name='train', hash_buckets=6),
        example_gen_pb2.SplitConfig.Split(name='eval', hash_buckets=2),
        example_gen_pb2.SplitConfig.Split(name='test', hash_buckets=2)
    ]))

example_gen = CsvExampleGen(input_base=data_dir, output_config=output)

context.run(example_gen)
# Out:
# WARNING:root:Make sure that locally built Python SDK docker image has Python 3.7 interpreter.
# ExecutionResult(
#     component_id: CsvExampleGen
#     execution_id: 2
#     outputs:
#         examples: Channel(
#             type_name: Examples
#             artifacts: [Artifact(artifact: id: 2
#         type_id: 5
#         uri: "tfx/CsvExampleGen/examples/2"
#         properties {
#           key: "split_names"
#           value {
#             string_value: "[\"train\", \"eval\", \"test\"]"
#           }
#         }
#         custom_properties {
#           key: "input_fingerprint"
#           value {
#             string_value: "split:single_split,num_files:1,total_bytes:78956236,xor_checksum:1629119443,sum_checksum:1629119443"
#           }
#         }
#         custom_properties {
#           key: "payload_format"
#           value {
#             string_value: "FORMAT_TF_EXAMPLE"
#           }
#         }
#         custom_properties {
#           key: "span"
#           value {
#             string_value: "0"
#           }
#         }
#         custom_properties {
#           key: "state"
#           value {
#             string_value: "published"
#           }
#         }
#         state: LIVE
#         , artifact_type: id: 5
#         name: "Examples"
#         properties {
#           key: "span"
#           value: INT
#         }
#         properties {
#           key: "split_names"
#           value: STRING
#         }
#         properties {
#           key: "version"
#           value: INT
#         }
#         )]
#             additional_properties: {}
#             additional_custom_properties: {}
#         ))

# %% [markdown]
# ### Preserve existing splits

# %%
# !mkdir -p data/train
# !mkdir -p data/eval
# !mkdir -p data/test

# %%
df.iloc[:20000].to_csv('data/train/20k-consumer-complaints-training.csv', index=False)
df.iloc[20000:24000].to_csv('data/eval/4k-consumer-complaints-eval.csv', index=False)
df.iloc[24000:26000].to_csv('data/test/2k-consumer-complaints-test.csv', index=False)

# %%
input = example_gen_pb2.Input(splits=[
    example_gen_pb2.Input.Split(name='train', pattern='train/*'),
    example_gen_pb2.Input.Split(name='eval', pattern='eval/*'),
    example_gen_pb2.Input.Split(name='test', pattern='test/*')
])

example_gen = CsvExampleGen(input_base=data_dir, input_config=input)
context.run(example_gen)
# Out:
# WARNING:root:Make sure that locally built Python SDK docker image has Python 3.7 interpreter.
# ExecutionResult(
#     component_id: CsvExampleGen
#     execution_id: 3
#     outputs:
#         examples: Channel(
#             type_name: Examples
#             artifacts: [Artifact(artifact: id: 3
#         type_id: 5
#         uri: "tfx/CsvExampleGen/examples/3"
#         properties {
#           key: "split_names"
#           value {
#             string_value: "[\"train\", \"eval\", \"test\"]"
#           }
#         }
#         custom_properties {
#           key: "input_fingerprint"
#           value {
#             string_value: "split:train,num_files:1,total_bytes:23608185,xor_checksum:1629119519,sum_checksum:1629119519\nsplit:eval,num_files:1,total_bytes:4759360,xor_checksum:1629119519,sum_checksum:1629119519\nsplit:test,num_files:1,total_bytes:2428892,xor_checksum:1629119519,sum_checksum:1629119519"
#           }
#         }
#         custom_properties {
#           key: "payload_format"
#           value {
#             string_value: "FORMAT_TF_EXAMPLE"
#           }
#         }
#         custom_properties {
#           key: "span"
#           value {
#             string_value: "0"
#           }
#         }
#         custom_properties {
#           key: "state"
#           value {
#             string_value: "published"
#           }
#         }
#         state: LIVE
#         , artifact_type: id: 5
#         name: "Examples"
#         properties {
#           key: "span"
#           value: INT
#         }
#         properties {
#           key: "split_names"
#           value: STRING
#         }
#         properties {
#           key: "version"
#           value: INT
#         }
#         )]
#             additional_properties: {}
#             additional_custom_properties: {}
#         ))

# %% [markdown]
# ### Spanning Datasets

# %%
# !mkdir -p data/export-0
# !mkdir -p data/export-1
# !mkdir -p data/export-2

# %%
df.iloc[:20000].to_csv('data/export-0/20k-consumer-complaints.csv', index=False)
df.iloc[24000].to_csv('data/export-1/24k-consumer-complaints.csv', index=False)
df.iloc[26000].to_csv('data/export-2/26k-consumer-complaints.csv', index=False)

# %%
input = example_gen_pb2.Input(splits=[
    example_gen_pb2.Input.Split(pattern='export-{SPAN}/*')
])

example_gen = CsvExampleGen(input_base=data_dir, input_config=input)
context.run(example_gen)
# Out:
# WARNING:root:Make sure that locally built Python SDK docker image has Python 3.7 interpreter.
# ExecutionResult(
#     component_id: CsvExampleGen
#     execution_id: 4
#     outputs:
#         examples: Channel(
#             type_name: Examples
#             artifacts: [Artifact(artifact: id: 4
#         type_id: 5
#         uri: "tfx/CsvExampleGen/examples/4"
#         properties {
#           key: "split_names"
#           value {
#             string_value: "[\"train\", \"eval\"]"
#           }
#         }
#         custom_properties {
#           key: "input_fingerprint"
#           value {
#             string_value: "split:,num_files:1,total_bytes:412,xor_checksum:1629119534,sum_checksum:1629119534"
#           }
#         }
#         custom_properties {
#           key: "payload_format"
#           value {
#             string_value: "FORMAT_TF_EXAMPLE"
#           }
#         }
#         custom_properties {
#           key: "span"
#           value {
#             string_value: "2"
#           }
#         }
#         custom_properties {
#           key: "state"
#           value {
#             string_value: "published"
#           }
#         }
#         state: LIVE
#         , artifact_type: id: 5
#         name: "Examples"
#         properties {
#           key: "span"
#           value: INT
#         }
#         properties {
#           key: "split_names"
#           value: STRING
#         }
#         properties {
#           key: "version"
#           value: INT
#         }
#         )]
#             additional_properties: {}
#             additional_custom_properties: {}
#         ))
